# %%
import os
import numpy as np
import pandas as pd
import librosa
import librosa.display
from tqdm import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint
from datetime import datetime

audio_dataset_path = 'UrbanSound8K/audio/'
metadata = pd.read_csv('UrbanSound8K/metadata/UrbanSound8K.csv')

max_length = 174
def features_extractor(file, max_length=174):
    audio, sample_rate = librosa.load(file, res_type='kaiser_fast') 
    spectrogram = librosa.feature.melspectrogram(y=audio, sr=sample_rate, n_mels=128)
    spectrogram = librosa.power_to_db(spectrogram, ref=np.max)
    
    if spectrogram.shape[1] < max_length:
        pad_width = max_length - spectrogram.shape[1]
        spectrogram = np.pad(spectrogram, pad_width=((0, 0), (0, pad_width)), mode='constant')
    else:
        spectrogram = spectrogram[:, :max_length]
    
    return spectrogram

extracted_features = []
for index_num, row in tqdm(metadata.iterrows(), total=metadata.shape[0]):
    file_name = os.path.join(os.path.abspath(audio_dataset_path), 'fold'+str(row["fold"])+'/', str(row["slice_file_name"]))
    final_class_labels = row["class"]
    data = features_extractor(file_name, max_length)
    extracted_features.append([data, final_class_labels])

extracted_features_df = pd.DataFrame(extracted_features, columns=['feature', 'class'])
X = np.array(extracted_features_df['feature'].tolist())
y = np.array(extracted_features_df['class'].tolist())

labelencoder = LabelEncoder()
y = to_categorical(labelencoder.fit_transform(y))

X = X[..., np.newaxis]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

model = Sequential()

model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(X_train.shape[1], X_train.shape[2], 1)))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.3))

model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.3))

model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.3))

model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(y.shape[1], activation='softmax'))

model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

checkpointer = ModelCheckpoint(filepath='saved_models/audio_classification_cnn3.keras', 
                               verbose=1, save_best_only=True)
start = datetime.now()

num_epochs = 100
num_batch_size = 32

model.fit(X_train, y_train, batch_size=num_batch_size, epochs=num_epochs, validation_data=(X_test, y_test), callbacks=[checkpointer], verbose=1)

duration = datetime.now() - start
print("Training completed in time: ", duration)

test_accuracy = model.evaluate(X_test, y_test, verbose=0)
print("Test accuracy:", test_accuracy[1])
# Out:
#  41%|███████████████████████████████▋                                              | 3554/8732 [04:35<06:30, 13.27it/s]D:\conda\envs\env\lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1323
#   warnings.warn(
#  95%|██████████████████████████████████████████████████████████████████████████▎   | 8325/8732 [10:27<00:21, 18.93it/s]D:\conda\envs\env\lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1103
#   warnings.warn(
# D:\conda\envs\env\lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1523
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████| 8732/8732 [10:56<00:00, 13.30it/s]
# D:\conda\envs\env\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/100
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step - accuracy: 0.1373 - loss: 13.9421
# Epoch 1: val_loss improved from inf to 2.12780, saving model to saved_models/audio_classification_cnn3.keras
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 62s 274ms/step - accuracy: 0.1374 - loss: 13.9005 - val_accuracy: 0.1809 - val_loss: 2.1278
# Epoch 2/100
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.1639 - loss: 2.1459
# Epoch 2: val_loss did not improve from 2.12780
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 59s 268ms/step - accuracy: 0.1639 - loss: 2.1458 - val_accuracy: 0.1431 - val_loss: 2.1758
# Epoch 3/100
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.1731 - loss: 2.1023
# Epoch 3: val_loss improved from 2.12780 to 2.12080, saving model to saved_models/audio_classification_cnn3.keras
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 59s 269ms/step - accuracy: 0.1731 - loss: 2.1022 - val_accuracy: 0.2078 - val_loss: 2.1208
# Epoch 4/100
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.1811 - loss: 2.0702
# Epoch 4: val_loss improved from 2.12080 to 2.02821, saving model to saved_models/audio_classification_cnn3.keras
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 59s 270ms/step - accuracy: 0.1811 - loss: 2.0701 - val_accuracy: 0.2833 - val_loss: 2.0282
# Epoch 5/100
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step - accuracy: 0.2176 - loss: 1.9854
# Epoch 5: val_loss improved from 2.02821 to 1.88008, saving model to saved_models/audio_classification_cnn3.keras
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 59s 271ms/step - accuracy: 0.2177 - loss: 1.9853 - val_accuracy: 0.3360 - val_loss: 1.8801
# Epoch 6/100
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step - accuracy: 0.2953 - loss: 1.8687
# Epoch 6: val_loss improved from 1.88008 to 1.62243, saving model to saved_models/audio_classification_cnn3.keras
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 60s 272ms/step - accuracy: 0.2954 - loss: 1.8685 - val_accuracy: 0.4637 - val_loss: 1.6224
# Epoch 7/100
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.3686 - loss: 1.6834
# Epoch 7: val_loss did not improve from 1.62243
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 59s 270ms/step - accuracy: 0.3687 - loss: 1.6833 - val_accuracy: 0.2971 - val_loss: 1.9358
# Epoch 8/100
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - accuracy: 0.4275 - loss: 1.5333
# Epoch 8: val_loss did not improve from 1.62243
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 60s 273ms/step - accuracy: 0.4275 - loss: 1.5333 - val_accuracy: 0.4013 - val_loss: 1.6727
# Epoch 9/100
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step - accuracy: 0.4536 - loss: 1.4762
# Epoch 9: val_loss did not improve from 1.62243
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 60s 273ms/step - accuracy: 0.4536 - loss: 1.4761 - val_accuracy: 0.4201 - val_loss: 1.6361
# Epoch 10/100
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - accuracy: 0.4796 - loss: 1.4117
# Epoch 10: val_loss improved from 1.62243 to 1.40817, saving model to saved_models/audio_classification_cnn3.keras
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 60s 273ms/step - accuracy: 0.4797 - loss: 1.4115 - val_accuracy: 0.5192 - val_loss: 1.4082
# Epoch 11/100
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step - accuracy: 0.5222 - loss: 1.3110
# Epoch 11: val_loss improved from 1.40817 to 1.14156, saving model to saved_models/audio_classification_cnn3.keras
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 59s 272ms/step - accuracy: 0.5223 - loss: 1.3109 - val_accuracy: 0.6480 - val_loss: 1.1416
# Epoch 12/100
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - accuracy: 0.5576 - loss: 1.2314
# Epoch 12: val_loss improved from 1.14156 to 1.10671, saving model to saved_models/audio_classification_cnn3.keras
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 60s 273ms/step - accuracy: 0.5576 - loss: 1.2313 - val_accuracy: 0.6199 - val_loss: 1.1067
# Epoch 13/100
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step - accuracy: 0.5912 - loss: 1.1348
# Epoch 13: val_loss improved from 1.10671 to 0.97109, saving model to saved_models/audio_classification_cnn3.keras
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 60s 274ms/step - accuracy: 0.5912 - loss: 1.1347 - val_accuracy: 0.6760 - val_loss: 0.9711
# Epoch 14/100
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - accuracy: 0.6309 - loss: 1.0386
# Epoch 14: val_loss did not improve from 0.97109
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 60s 272ms/step - accuracy: 0.6309 - loss: 1.0386 - val_accuracy: 0.6629 - val_loss: 0.9858
# Epoch 15/100
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.6512 - loss: 0.9950
# Epoch 15: val_loss improved from 0.97109 to 0.79975, saving model to saved_models/audio_classification_cnn3.keras
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 59s 271ms/step - accuracy: 0.6512 - loss: 0.9950 - val_accuracy: 0.7241 - val_loss: 0.7997
# Epoch 16/100
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - accuracy: 0.6776 - loss: 0.9007
# Epoch 16: val_loss improved from 0.79975 to 0.73484, saving model to saved_models/audio_classification_cnn3.keras
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 60s 273ms/step - accuracy: 0.6776 - loss: 0.9007 - val_accuracy: 0.7636 - val_loss: 0.7348
# Epoch 17/100
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - accuracy: 0.7017 - loss: 0.8354
# Epoch 17: val_loss did not improve from 0.73484
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 60s 272ms/step - accuracy: 0.7017 - loss: 0.8355 - val_accuracy: 0.7682 - val_loss: 0.7409
# Epoch 18/100
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step - accuracy: 0.7210 - loss: 0.7935
# Epoch 18: val_loss improved from 0.73484 to 0.65049, saving model to saved_models/audio_classification_cnn3.keras
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 60s 272ms/step - accuracy: 0.7211 - loss: 0.7935 - val_accuracy: 0.7899 - val_loss: 0.6505
# Epoch 19/100
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.7151 - loss: 0.7738
# Epoch 19: val_loss improved from 0.65049 to 0.61709, saving model to saved_models/audio_classification_cnn3.keras
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 59s 271ms/step - accuracy: 0.7151 - loss: 0.7737 - val_accuracy: 0.7888 - val_loss: 0.6171
# Epoch 20/100
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.7356 - loss: 0.7334
# Epoch 20: val_loss improved from 0.61709 to 0.56904, saving model to saved_models/audio_classification_cnn3.keras
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 82s 270ms/step - accuracy: 0.7357 - loss: 0.7333 - val_accuracy: 0.8231 - val_loss: 0.5690
# Epoch 21/100
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.7599 - loss: 0.6812
# Epoch 21: val_loss improved from 0.56904 to 0.53084, saving model to saved_models/audio_classification_cnn3.keras
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 59s 271ms/step - accuracy: 0.7599 - loss: 0.6812 - val_accuracy: 0.8306 - val_loss: 0.5308
# Epoch 22/100
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.7694 - loss: 0.6528
# Epoch 22: val_loss did not improve from 0.53084
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 59s 269ms/step - accuracy: 0.7694 - loss: 0.6528 - val_accuracy: 0.8277 - val_loss: 0.5437
# Epoch 23/100
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.7901 - loss: 0.5947
# Epoch 23: val_loss did not improve from 0.53084
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 59s 269ms/step - accuracy: 0.7901 - loss: 0.5947 - val_accuracy: 0.8185 - val_loss: 0.5358
# Epoch 24/100
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.8080 - loss: 0.5740
# Epoch 24: val_loss improved from 0.53084 to 0.48028, saving model to saved_models/audio_classification_cnn3.keras
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 59s 271ms/step - accuracy: 0.8079 - loss: 0.5740 - val_accuracy: 0.8500 - val_loss: 0.4803
# Epoch 25/100
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.8091 - loss: 0.5389
# Epoch 25: val_loss improved from 0.48028 to 0.47052, saving model to saved_models/audio_classification_cnn3.keras
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 59s 270ms/step - accuracy: 0.8091 - loss: 0.5389 - val_accuracy: 0.8569 - val_loss: 0.4705
# Epoch 26/100
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.
val_loss did not improve from 0.40537
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 60s 275ms/step - accuracy: 0.9486 - loss: 0.1456 - val_accuracy: 0.8861 - val_loss: 0.5696
# Epoch 90/100
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.9476 - loss: 0.1746
# Epoch 90: val_loss did not improve from 0.40537
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 60s 274ms/step - accuracy: 0.9476 - loss: 0.1747 - val_accuracy: 0.8952 - val_loss: 0.4534
# Epoch 91/100
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 0.9539 - loss: 0.1407
# Epoch 91: val_loss did not improve from 0.40537
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 60s 272ms/step - accuracy: 0.9539 - loss: 0.1407 - val_accuracy: 0.9004 - val_loss: 0.5687
# Epoch 92/100
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.9503 - loss: 0.1487
# Epoch 92: val_loss did not improve from 0.40537
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 60s 274ms/step - accuracy: 0.9503 - loss: 0.1487 - val_accuracy: 0.9061 - val_loss: 0.4911
# Epoch 93/100
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.9481 - loss: 0.1670
# Epoch 93: val_loss did not improve from 0.40537
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 60s 275ms/step - accuracy: 0.9481 - loss: 0.1671 - val_accuracy: 0.8912 - val_loss: 0.5354
# Epoch 94/100
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 0.9389 - loss: 0.1968
# Epoch 94: val_loss did not improve from 0.40537
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 60s 275ms/step - accuracy: 0.9389 - loss: 0.1969 - val_accuracy: 0.9004 - val_loss: 0.5240
# Epoch 95/100
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - accuracy: 0.9414 - loss: 0.1804
# Epoch 95: val_loss did not improve from 0.40537
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 60s 273ms/step - accuracy: 0.9414 - loss: 0.1804 - val_accuracy: 0.8815 - val_loss: 0.5487
# Epoch 96/100
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.9430 - loss: 0.1634
# Epoch 96: val_loss did not improve from 0.40537
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 60s 274ms/step - accuracy: 0.9430 - loss: 0.1634 - val_accuracy: 0.8867 - val_loss: 0.5874
# Epoch 97/100
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 0.9426 - loss: 0.1857
# Epoch 97: val_loss did not improve from 0.40537
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 60s 275ms/step - accuracy: 0.9426 - loss: 0.1857 - val_accuracy: 0.8930 - val_loss: 0.4663
# Epoch 98/100
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.9463 - loss: 0.1770
# Epoch 98: val_loss did not improve from 0.40537
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 60s 274ms/step - accuracy: 0.9463 - loss: 0.1770 - val_accuracy: 0.8964 - val_loss: 0.4715
# Epoch 99/100
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step - accuracy: 0.9526 - loss: 0.1433
# Epoch 99: val_loss did not improve from 0.40537
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 60s 273ms/step - accuracy: 0.9526 - loss: 0.1434 - val_accuracy: 0.8912 - val_loss: 0.4668
# Epoch 100/100
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.9526 - loss: 0.1350
# Epoch 100: val_loss did not improve from 0.40537
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 60s 274ms/step - accuracy: 0.9525 - loss: 0.1350 - val_accuracy: 0.8941 - val_loss: 0.5351
# Training completed in time:  1:41:25.291258
# Test accuracy: 0.8941041827201843

# %%
from tensorflow.keras.models import load_model
import numpy as np
import librosa

class_names = ['air_conditioner', 'car_horn', 'chileren_playing', 'dog_bark', 'drilling', 'engine_idling', 'gun_shot', 'jackhammer', 'siren',
              'street_music', ]

def predict_audio_class(file_path, model_path='saved_models/audio_classification_cnn3.keras', max_length=174):
    model = load_model(model_path)
    
    def features_extractor(file, max_length=174):
        audio, sample_rate = librosa.load(file, res_type='kaiser_fast')
        spectrogram = librosa.feature.melspectrogram(y=audio, sr=sample_rate, n_mels=128)
        spectrogram = librosa.power_to_db(spectrogram, ref=np.max)
        
        if spectrogram.shape[1] < max_length:
            pad_width = max_length - spectrogram.shape[1]
            spectrogram = np.pad(spectrogram, pad_width=((0, 0), (0, pad_width)), mode='constant')
        else:
            spectrogram = spectrogram[:, :max_length]
        
        return spectrogram
    
    features = features_extractor(file_path, max_length)
    
    features = features[np.newaxis, ..., np.newaxis]
    
    predictions = model.predict(features)
    
    predicted_class_index = np.argmax(predictions, axis=1)[0]
    
    predicted_class_name = class_names[predicted_class_index]
    
    return predicted_class_name

file_path = 'UrbanSound8k/100263-2-0-3.wav'
predicted_class_name = predict_audio_class(file_path)
print(f'Predicted class name: {predicted_class_name}')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# Predicted class name: chileren_playing
